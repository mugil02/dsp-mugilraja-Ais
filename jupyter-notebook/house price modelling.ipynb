# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %%
data = df_train = pd.read_csv('/Users/mugilrajark/Downloads/house-prices-advanced-regression-techniques/train.csv')
print(" Data shape -->", data.shape)
data.head()
# Out:
#  Data shape --> (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
cols_not_useful = ['Id', 'MoSold', 'YrSold', 'GarageYrBlt','MasVnrArea', 'LotFrontage']
categorical_cols = [ 'MSSubClass']

# %%
def get_numerical_features(df):
    Numerical_columns = list(df.select_dtypes("int").columns)
    Numerical_columns_float = list(df.select_dtypes("float").columns)
    filtered_numerical_columns = list(Numerical_columns) + list(Numerical_columns_float) 
    filtered_numerical_columns =  set(filtered_numerical_columns) - set(cols_not_useful)
    filtered_numerical_columns =  filtered_numerical_columns - set(categorical_cols)
    return list(filtered_numerical_columns)

# %%
def get_categorical_features(df):
    categorical_features = list(df.select_dtypes("object").columns)
    categorical_features = list(set(categorical_cols + categorical_features))
    return categorical_features

numerical_cols =  get_numerical_features(data)
categorical_features =  get_categorical_features(data)

# %%
categorical_features
# Out:
# ['ExterCond',
#  'Condition1',
#  'PoolQC',
#  'RoofStyle',
#  'ExterQual',
#  'RoofMatl',
#  'SaleCondition',
#  'LotShape',
#  'GarageCond',
#  'LandSlope',
#  'BldgType',
#  'Heating',
#  'BsmtFinType1',
#  'CentralAir',
#  'Foundation',
#  'KitchenQual',
#  'Street',
#  'LandContour',
#  'Electrical',
#  'FireplaceQu',
#  'MiscFeature',
#  'MasVnrType',
#  'MSZoning',
#  'LotConfig',
#  'BsmtFinType2',
#  'GarageFinish',
#  'SaleType',
#  'Fence',
#  'BsmtQual',
#  'MSSubClass',
#  'BsmtCond',
#  'Exterior1st',
#  'Neighborhood',
#  'HouseStyle',
#  'PavedDrive',
#  'Condition2',
#  'Utilities',
#  'Exterior2nd',
#  'GarageType',
#  'Functional',
#  'GarageQual',
#  'BsmtExposure',
#  'Alley',
#  'HeatingQC']

# %%
na_fill_dict = {'Alley' : 'No alley access',
                'BsmtQual' : 'No Basement',
                'BsmtCond' : 'No Basement',
                'BsmtExposure' : 'No Basement',
                'BsmtFinType1' : 'No Basement',
                'BsmtFinType2' : 'No Basement',
                'FireplaceQu' : 'No Fireplace',
                'GarageType': 'No Garage',
                'GarageFinish': 'No Garage',
                'GarageQual': 'No Garage',
                'GarageType': 'No Garage',
                'GarageCond': 'No Garage',
                'PoolQC': 'No Pool',
                'Fence': 'No Fence',
                'MiscFeature': 'None'
}

def fill_na_categorical(df, na_fill_dict):
    for col in na_fill_dict:
         df[col].fillna(value=na_fill_dict[col], inplace=True)
    return df

data = fill_na_categorical(data, na_fill_dict)

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street            Alley  \
# 0        1          60       RL         65.0     8450   Pave  No alley access
# 1        2          20       RL         80.0     9600   Pave  No alley access
# 2        3          60       RL         68.0    11250   Pave  No alley access
# 3        4          70       RL         60.0     9550   Pave  No alley access
# 4        5          60       RL         84.0    14260   Pave  No alley access
# ...    ...         ...      ...          ...      ...    ...              ...
# 1455  1456          60       RL         62.0     7917   Pave  No alley access
# 1456  1457          20       RL         85.0    13175   Pave  No alley access
# 1457  1458          70       RL         66.0     9042   Pave  No alley access
# 1458  1459          20       RL         68.0     9717   Pave  No alley access
# 1459  1460          20       RL         75.0     9937   Pave  No alley access
#
#      LotShape LandContour Utilities  ... PoolArea   PoolQC     Fence  \
# 0         Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 1         Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 2         IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 3         IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 4         IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# ...       ...         ...       ...  ...      ...      ...       ...
# 1455      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 1456      Reg         Lvl    AllPub  ...        0  No Pool     MnPrv
# 1457      Reg         Lvl    AllPub  ...        0  No Pool     GdPrv
# 1458      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 1459      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
#
#      MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0           None       0      2   2008        WD         Normal     208500
# 1           None       0      5   2007        WD         Normal     181500
# 2           None       0      9   2008        WD         Normal     223500
# 3           None       0      2   2006        WD        Abnorml     140000
# 4           None       0     12   2008        WD         Normal     250000
# ...          ...     ...    ...    ...       ...            ...        ...
# 1455        None       0      8   2007        WD         Normal     175000
# 1456        None       0      2   2010        WD         Normal     210000
# 1457        Shed    2500      5   2010        WD         Normal     266500
# 1458        None       0      4   2010        WD         Normal     142125
# 1459        None       0      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
data[numerical_cols].isna().sum()
# Out:
# BedroomAbvGr     0
# HalfBath         0
# BsmtFinSF1       0
# FullBath         0
# 1stFlrSF         0
# 3SsnPorch        0
# YearRemodAdd     0
# OverallCond      0
# EnclosedPorch    0
# KitchenAbvGr     0
# OverallQual      0
# SalePrice        0
# LowQualFinSF     0
# GrLivArea        0
# MiscVal          0
# TotalBsmtSF      0
# Fireplaces       0
# TotRmsAbvGrd     0
# YearBuilt        0
# GarageArea       0
# BsmtHalfBath     0
# PoolArea         0
# OpenPorchSF      0
# BsmtFinSF2       0
# GarageCars       0
# BsmtUnfSF        0
# LotArea          0
# BsmtFullBath     0
# 2ndFlrSF         0
# WoodDeckSF       0
# ScreenPorch      0
# dtype: int64

# %%
for col in list(categorical_features):
    print(f'{col}   -- >',sum(data[col].isna()))
# Out:
# ExterCond   -- > 0
# Condition1   -- > 0
# PoolQC   -- > 0
# RoofStyle   -- > 0
# ExterQual   -- > 0
# RoofMatl   -- > 0
# SaleCondition   -- > 0
# LotShape   -- > 0
# GarageCond   -- > 0
# LandSlope   -- > 0
# BldgType   -- > 0
# Heating   -- > 0
# BsmtFinType1   -- > 0
# CentralAir   -- > 0
# Foundation   -- > 0
# KitchenQual   -- > 0
# Street   -- > 0
# LandContour   -- > 0
# Electrical   -- > 1
# FireplaceQu   -- > 0
# MiscFeature   -- > 0
# MasVnrType   -- > 8
# MSZoning   -- > 0
# LotConfig   -- > 0
# BsmtFinType2   -- > 0
# GarageFinish   -- > 0
# SaleType   -- > 0
# Fence   -- > 0
# BsmtQual   -- > 0
# MSSubClass   -- > 0
# BsmtCond   -- > 0
# Exterior1st   -- > 0
# Neighborhood   -- > 0
# HouseStyle   -- > 0
# PavedDrive   -- > 0
# Condition2   -- > 0
# Utilities   -- > 0
# Exterior2nd   -- > 0
# GarageType   -- > 0
# Functional   -- > 0
# GarageQual   -- > 0
# BsmtExposure   -- > 0
# Alley   -- > 0
# HeatingQC   -- > 0

# %%
pd.options.mode.chained_assignment = None

# %%
data[categorical_features].dropna(inplace=True)

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street            Alley  \
# 0        1          60       RL         65.0     8450   Pave  No alley access
# 1        2          20       RL         80.0     9600   Pave  No alley access
# 2        3          60       RL         68.0    11250   Pave  No alley access
# 3        4          70       RL         60.0     9550   Pave  No alley access
# 4        5          60       RL         84.0    14260   Pave  No alley access
# ...    ...         ...      ...          ...      ...    ...              ...
# 1455  1456          60       RL         62.0     7917   Pave  No alley access
# 1456  1457          20       RL         85.0    13175   Pave  No alley access
# 1457  1458          70       RL         66.0     9042   Pave  No alley access
# 1458  1459          20       RL         68.0     9717   Pave  No alley access
# 1459  1460          20       RL         75.0     9937   Pave  No alley access
#
#      LotShape LandContour Utilities  ... PoolArea   PoolQC     Fence  \
# 0         Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 1         Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 2         IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 3         IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# 4         IR1         Lvl    AllPub  ...        0  No Pool  No Fence
# ...       ...         ...       ...  ...      ...      ...       ...
# 1455      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 1456      Reg         Lvl    AllPub  ...        0  No Pool     MnPrv
# 1457      Reg         Lvl    AllPub  ...        0  No Pool     GdPrv
# 1458      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
# 1459      Reg         Lvl    AllPub  ...        0  No Pool  No Fence
#
#      MiscFeature MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0           None       0      2   2008        WD         Normal     208500
# 1           None       0      5   2007        WD         Normal     181500
# 2           None       0      9   2008        WD         Normal     223500
# 3           None       0      2   2006        WD        Abnorml     140000
# 4           None       0     12   2008        WD         Normal     250000
# ...          ...     ...    ...    ...       ...            ...        ...
# 1455        None       0      8   2007        WD         Normal     175000
# 1456        None       0      2   2010        WD         Normal     210000
# 1457        Shed    2500      5   2010        WD         Normal     266500
# 1458        None       0      4   2010        WD         Normal     142125
# 1459        None       0      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
data[numerical_cols].corr()[['SalePrice']].sort_values("SalePrice", ascending=False)
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# ScreenPorch     0.111447
# PoolArea        0.092404
# 3SsnPorch       0.044584
# BsmtFinSF2     -0.011378
# BsmtHalfBath   -0.016844
# MiscVal        -0.021190
# LowQualFinSF   -0.025606
# OverallCond    -0.077856
# EnclosedPorch  -0.128578
# KitchenAbvGr   -0.135907

# %%
non_correlated_cols = ['PoolArea', 'KitchenAbvGr', 'EnclosedPorch', 'BsmtFinSF2', 'MiscVal', 'BsmtHalfBath',
                       'LowQualFinSF','3SsnPorch','ScreenPorch','OverallCond']

# %%
final_numerical_cols = list(set(numerical_cols) - set(non_correlated_cols))
final_categorical_cols = list(set(categorical_features) - set(get_categorical_features(data)))

# %%
preprocessed_df = data[list(final_categorical_cols) + list(final_numerical_cols) ]
preprocessed_df = pd.get_dummies(data=preprocessed_df, columns=final_categorical_cols)

# %%
train, test = train_test_split(preprocessed_df, test_size=0.2)
y = train['SalePrice']
X = train.drop(['SalePrice'], axis=1)

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'n_estimators' : [10,30, 50, 70, 100, 200], 'min_samples_leaf':[2,5,10]}
model = RandomForestRegressor()
reg = GridSearchCV(model, parameters, verbose=3,cv=10)
reg.fit(X, y)
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV 1/10] END min_samples_leaf=2, n_estimators=10;, score=0.825 total time=   0.1s
# [CV 2/10] END min_samples_leaf=2, n_estimators=10;, score=0.881 total time=   0.1s
# [CV 3/10] END min_samples_leaf=2, n_estimators=10;, score=0.830 total time=   0.1s
# [CV 4/10] END min_samples_leaf=2, n_estimators=10;, score=0.880 total time=   0.1s
# [CV 5/10] END min_samples_leaf=2, n_estimators=10;, score=0.873 total time=   0.1s
# [CV 6/10] END min_samples_leaf=2, n_estimators=10;, score=0.668 total time=   0.1s
# [CV 7/10] END min_samples_leaf=2, n_estimators=10;, score=0.844 total time=   0.1s
# [CV 8/10] END min_samples_leaf=2, n_estimators=10;, score=0.801 total time=   0.1s
# [CV 9/10] END min_samples_leaf=2, n_estimators=10;, score=0.725 total time=   0.1s
# [CV 10/10] END min_samples_leaf=2, n_estimators=10;, score=0.861 total time=   0.1s
# [CV 1/10] END min_samples_leaf=2, n_estimators=30;, score=0.870 total time=   0.2s
# [CV 2/10] END min_samples_leaf=2, n_estimators=30;, score=0.887 total time=   0.2s
# [CV 3/10] END min_samples_leaf=2, n_estimators=30;, score=0.835 total time=   0.2s
# [CV 4/10] END min_samples_leaf=2, n_estimators=30;, score=0.879 total time=   0.2s
# [CV 5/10] END min_samples_leaf=2, n_estimators=30;, score=0.879 total time=   0.2s
# [CV 6/10] END min_samples_leaf=2, n_estimators=30;, score=0.669 total time=   0.2s
# [CV 7/10] END min_samples_leaf=2, n_estimators=30;, score=0.896 total time=   0.2s
# [CV 8/10] END min_samples_leaf=2, n_estimators=30;, score=0.796 total time=   0.2s
# [CV 9/10] END min_samples_leaf=2, n_estimators=30;, score=0.710 total time=   0.2s
# [CV 10/10] END min_samples_leaf=2, n_estimators=30;, score=0.885 total time=   0.2s
# [CV 1/10] END min_samples_leaf=2, n_estimators=50;, score=0.863 total time=   0.4s
# [CV 2/10] END min_samples_leaf=2, n_estimators=50;, score=0.893 total time=   0.4s
# [CV 3/10] END min_samples_leaf=2, n_estimators=50;, score=0.844 total time=   0.4s
# [CV 4/10] END min_samples_leaf=2, n_estimators=50;, score=0.878 total time=   0.4s
# [CV 5/10] END min_samples_leaf=2, n_estimators=50;, score=0.885 total time=   0.4s
# [CV 6/10] END min_samples_leaf=2, n_estimators=50;, score=0.689 total time=   0.4s
# [CV 7/10] END min_samples_leaf=2, n_estimators=50;, score=0.875 total time=   0.4s
# [CV 8/10] END min_samples_leaf=2, n_estimators=50;, score=0.817 total time=   0.4s
# [CV 9/10] END min_samples_leaf=2, n_estimators=50;, score=0.718 total time=   0.4s
# [CV 10/10] END min_samples_leaf=2, n_estimators=50;, score=0.892 total time=   0.4s
# [CV 1/10] END min_samples_leaf=2, n_estimators=70;, score=0.865 total time=   0.5s
# [CV 2/10] END min_samples_leaf=2, n_estimators=70;, score=0.908 total time=   0.5s
# [CV 3/10] END min_samples_leaf=2, n_estimators=70;, score=0.844 total time=   0.5s
# [CV 4/10] END min_samples_leaf=2, n_estimators=70;, score=0.885 total time=   0.5s
# [CV 5/10] END min_samples_leaf=2, n_estimators=70;, score=0.877 total time=   0.5s
# [CV 6/10] END min_samples_leaf=2, n_estimators=70;, score=0.742 total time=   0.5s
# [CV 7/10] END min_samples_leaf=2, n_estimators=70;, score=0.877 total time=   0.5s
# [CV 8/10] END min_samples_leaf=2, n_estimators=70;, score=0.812 total time=   0.5s
# [CV 9/10] END min_samples_leaf=2, n_estimators=70;, score=0.716 total time=   0.5s
# [CV 10/10] END min_samples_leaf=2, n_estimators=70;, score=0.888 total time=   0.5s
# [CV 1/10] END min_samples_leaf=2, n_estimators=100;, score=0.874 total time=   0.7s
# [CV 2/10] END min_samples_leaf=2, n_estimators=100;, score=0.898 total time=   0.7s
# [CV 3/10] END min_samples_leaf=2, n_estimators=100;, score=0.843 total time=   0.7s
# [CV 4/10] END min_samples_leaf=2, n_estimators=100;, score=0.880 total time=   0.7s
# [CV 5/10] END min_samples_leaf=2, n_estimators=100;, score=0.884 total time=   0.7s
# [CV 6/10] END min_samples_leaf=2, n_estimators=100;, score=0.725 total time=   0.7s
# [CV 7/10] END min_samples_leaf=2, n_estimators=100;, score=0.890 total time=   0.7s
# [CV 8/10] END min_samples_leaf=2, n_estimators=100;, score=0.818 total time=   0.7s
# [CV 9/10] END min_samples_leaf=2, n_estimators=100;, score=0.726 total time=   0.7s
# [CV 10/10] END min_samples_leaf=2, n_estimators=100;, score=0.891 total time=   0.7s
# [CV 1/10] END min_samples_leaf=2, n_estimators=200;, score=0.858 total time=   1.4s
# [CV 2/10] END min_samples_leaf=2, n_estimators=200;, score=0.908 total time=   1.5s
# [CV 3/10] END min_samples_leaf=2, n_estimators=200;, score=0.853 total time=   1.5s
# [CV 4/10] END min_samples_leaf=2, n_estimators=200;, score=0.881 total time=   1.4s
# [CV 5/10] END min_samples_leaf=2, n_estimators=200;, score=0.880 total time=   1.4s
# [CV 6/10] END min_samples_leaf=2, n_estimators=200;, score=0.732 total time=   1.4s
# [CV 7/10] END min_samples_leaf=2, n_estimators=200;, score=0.883 total time=   1.5s
# [CV 8/10] END min_samples_leaf=2, n_estimators=200;, score=0.812 total time=   1.5s
# [CV 9/10] END min_samples_leaf=2, n_estimators=200;, score=0.728 total time=   1.4s
# [CV 10/10] END min_samples_leaf=2, n_estimators=200;, score=0.892 total time=   1.5s
# [CV 1/10] END min_samples_leaf=5, n_estimators=10;, score=0.826 total time=   0.1s
# [CV 2/10] END min_samples_leaf=5, n_estimators=10;, score=0.893 total time=   0.1s
# [CV 3/10] END min_samples_leaf=5, n_estimators=10;, score=0.845 total time=   0.1s
# [CV 4/10] END min_samples_leaf=5, n_estimators=10;, score=0.883 total time=   0.1s
# [CV 5/10] END min_samples_leaf=5, n_estimators=10;, score=0.861 total time=   0.1s
# [CV 6/10] END min_samples_leaf=5, n_estimators=10;, score=0.719 total time=   0.1s
# [CV 7/10] END min_samples_leaf=5, n_estimators=10;, score=0.869 total time=   0.1s
# [CV 8/10] END min_samples_leaf=5, n_estimators=10;, score=0.803 total time=   0.1s
# [CV 9/10] END min_samples_leaf=5, n_estimators=10;, score=0.734 total time=   0.1s
# [CV 10/10] END min_samples_leaf=5, n_estimators=10;, score=0.882 total time=   0.1s
# [CV 1/10] END min_samples_leaf=5, n_estimators=30;, score=0.832 total time=   0.2s
# [CV 2/10] END min_samples_leaf=5, n_estimators=30;, score=0.904 total time=   0.2s
# [CV 3/10] END min_samples_leaf=5, n_estimators=30;, score=0.849 total time=   0.2s
# [CV 4/10] END min_samples_leaf=5, n_estimators=30;, score=0.866 total time=   0.2s
# [CV 5/10] END min_samples_leaf=5, n_estimators=30;, score=0.873 total time=   0.2s
# [CV 6/10] END min_samples_leaf=5, n_estimators=30;, score=0.732 total time=   0.2s
# [CV 7/10] END min_samples_leaf=5, n_estimators=30;, score=0.875 total time=   0.2s
# [CV 8/10] END min_samples_leaf=5, n_estimators=30;, score=0.796 total time=   0.2s
# [CV 9/10] END min_samples_leaf=5, n_estimators=30;, score=0.730 total time=   0.2s
# [CV 10/10] END min_samples_leaf=5, n_estimators=30;, score=0.880 total time=   0.2s
# [CV 1/10] END min_samples_leaf=5, n_estimators=50;, score=0.844 total time=   0.3s
# [CV 2/10] END min_samples_leaf=5, n_estimators=50;, score=0.893 total time=   0.3s
# [CV 3/10] END min_samples_leaf=5, n_estimators=50;, score=0.844 total time=   0.3s
# [CV 4/10] END min_samples_leaf=5, n_estimators=50;, score=0.889 total time=   0.3s
# [CV 5/10] END min_samples_leaf=5, n_estimators=50;, score=0.875 total time=   0.3s
# [CV 6/10] END min_samples_leaf=5, n_estimators=50;, score=0.685 total time=   0.3s
# [CV 7/10] END min_samples_leaf=5, n_estimators=50;, score=0.878 total time=   0.3s
# [CV 8/10] END min_samples_leaf=5, n_estimators=50;, score=0.803 total time=   0.4s
# [CV 9/10] END min_samples_leaf=5, n_estimators=50;, score=0.727 total time=   0.4s
# [CV 10/10] END min_samples_leaf=5, n_estimators=50;, score=0.894 total time=   0.3s
# [CV 1/10] END min_samples_leaf=5, n_estimators=70;, score=0.842 total time=   0.5s
# [CV 2/10] END min_samples_leaf=5, n_estimators=70;, score=0.891 total time=   0.4s
# [CV 3/10] END min_samples_leaf=5, n_estimators=70;, score=0.840 total time=   0.4s
# [CV 4/10] END min_samples_leaf=5, n_estimators=70;, score=0.878 total time=   0.4s
# [CV 5/10] END min_samples_leaf=5, n_estimators=70;, score=0.868 total time=   0.4s
# [CV 6/10] END min_samples_leaf=5, n_estimators=70;, score=0.712 total time=   0.4s
# [CV 7/10] END min_samples_leaf=5, n_estimators=70;, score=0.875 total time=   0.4s
# [CV 8/10] END min_samples_leaf=5, n_estimators=70;, score=0.810 total time=   0.5s
# [CV 9/10] END min_samples_leaf=5, n_estimators=70;, score=0.737 total time=   0.4s
# [CV 10/10] END min_samples_leaf=5, n_estimators=70;, score=0.897 total time=   0.4s
# [CV 1/10] END min_samples_leaf=5, n_estimators=100;, score=0.841 total time=   0.6s
# [CV 2/10] END min_samples_leaf=5, n_estimators=100;, score=0.891 total time=   0.6s
# [CV 3/10] END min_samples_leaf=5, n_estimators=100;, score=0.835 total time=   0.6s
# [CV 4/10] END min_samples_leaf=5, n_estimators=100;, score=0.876 total time=   0.6s
# [CV 5/10] END min_samples_leaf=5, n_estimators=100;, score=0.876 total time=   0.6s
# [CV 6/10] END min_samples_leaf=5, n_estimators=100;, score=0.717 total time=   0.6s
# [CV 7/10] END min_samples_leaf=5, n_estimators=100;, score=0.884 total time=   0.6s
# [CV 8/10] END min_samples_leaf=5, n_estimators=100;, score=0.807 total time=   0.6s
# [CV 9/10] END min_samples_leaf=5, n_estimators=100;, score=0.733 total time=   0.6s
# [CV 10/10] END min_samples_leaf=5, n_estimators=100;, score=0.888 total time=   0.6s
# [CV 1/10] END min_samples_leaf=5, n_estimators=200;, score=0.839 total time=   1.2s
# [CV 2/10] END min_samples_leaf=5, n_estimators=200;, score=0.896 total time=   1.1s
# [CV 3/10] END min_samples_leaf=5, n_estimators=200;, score=0.838 total time=   1.1s
# [CV 4/10] END min_samples_leaf=5, n_estimators=200;, score=0.886 total time=   1.1s
# [CV 5/10] END min_samples_leaf=5, n_estimators=200;, score=0.876 total time=   1.2s
# [CV 6/10] END min_samples_leaf=5, n_estimators=200;, score=0.714 total time=   1.1s
# [CV 7/10] END min_samples_leaf=5, n_estimators=200;, score=0.880 total time=   1.1s
# [CV 8/10] END min_samples_leaf=5, n_estimators=200;, score=0.810 total time=   1.2s
# [CV 9/10] END min_samples_leaf=5, n_estimators=200;, score=0.739 total time=   1.2s
# [CV 10/10] END min_samples_leaf=5, n_estimators=200;, score=0.892 total time=   1.2s
# [CV 1/10] END min_samples_leaf=10, n_estimators=10;, score=0.809 total time=   0.1s
# [CV 2/10] END min_samples_leaf=10, n_estimators=10;, score=0.886 total time=   0.1s
# [CV 3/10] END min_samples_leaf=10, n_estimators=10;, score=0.790 total time=   0.1s
# [CV 4/10] END min_samples_leaf=10, n_estimators=10;, score=0.874 total time=   0.1s
# [CV 5/10] END min_samples_leaf=10, n_estimators=10;, score=0.857 total time=   0.1s
# [CV 6/10] END min_samples_leaf=10, n_estimators=10;, score=0.688 total time=   0.1s
# [CV 7/10] END min_samples_leaf=10, n_estimators=10;, score=0.867 total time=   0.1s
# [CV 8/10] END min_samples_leaf=10, n_estimators=10;, score=0.798 total time=   0.1s
# [CV 9/10] END min_samples_leaf=10, n_estimators=10;, score=0.713 total time=   0.1s
# [CV 10/10] END min_samples_leaf=10, n_estimators=10;, score=0.878 total time=   0.1s
# [CV 1/10] END min_samples_leaf=10, n_estimators=30;, score=0.810 total time=   0.2s
# [CV 2/10] END min_samples_leaf=10, n_estimators=30;, score=0.885 total time=   0.2s
# [CV 3/10] END min_samples_leaf=10, n_estimators=30;, score=0.810 total time=   0.2s
# [CV 4/10] END min_samples_leaf=10, n_estimators=30;, score=0.875 total time=   0.1s
# [CV 5/10] END min_samples_leaf=10, n_estimators=30;, score=0.866 total time=   0.2s
# [CV 6/10] END min_samples_leaf=10, n_estimators=30;, score=0.722 total time=   0.2s
# [CV 7/10] END min_samples_leaf=10, n_estimators=30;, score=0.878 total time=   0.2s
# [CV 8/10] END min_samples_leaf=10, n_estimators=30;, score=0.788 total time=   0.2s
# [CV 9/10] END min_samples_leaf=10, n_estimators=30;, score=0.730 total time=   0.2s
# [CV 10/10] END min_samples_leaf=10, n_estimators=30;, score=0.892 total time=   0.2s
# [CV 1/10] END min_samples_leaf=10, n_estimators=50;, score=0.822 total time=   0.2s
# [CV 2/10] END min_samples_leaf=10, n_estimators=50;, score=0.881 total time=   0.3s
# [CV 3/10] END min_samples_leaf=10, n_estimators=50;, score=0.814 total time=   0.2s
# [CV 4/10] END min_samples_leaf=10, n_estimators=50;, score=0.887 total time=   0.2s
# [CV 5/10] END min_samples_leaf=10, n_estimators=50;, score=0.857 total time=   0.3s
# [CV 6/10] END min_samples_leaf=10, n_estimators=50;, score=0.744 total time=   0.3s
# [CV 7/10] END min_samples_leaf=10, n_estimators=50;, score=0.868 total time=   0.2s
# [CV 8/10] END min_samples_leaf=10, n_estimators=50;, score=0.784 total time=   0.3s
# [CV 9/10] END min_samples_leaf=10, n_estimators=50;, score=0.733 total time=   0.2s
# [CV 10/10] END min_samples_leaf=10, n_estimators=50;, score=0.890 total time=   0.3s
# [CV 1/10] END min_samples_leaf=10, n_estimators=70;, score=0.819 total time=   0.3s
# [CV 2/10] END min_samples_leaf=10, n_estimators=70;, score=0.884 total time=   0.3s
# [CV 3/10] END min_samples_leaf=10, n_estimators=70;, score=0.807 total time=   0.3s
# [CV 4/10] END min_samples_leaf=10, n_estimators=70;, score=0.879 total time=   0.3s
# [CV 5/10] END min_samples_leaf=10, n_estimators=70;, score=0.863 total time=   0.4s
# [CV 6/10] END min_samples_leaf=10, n_estimators=70;, score=0.747 total time=   0.4s
# [CV 7/10] END min_samples_leaf=10, n_estimators=70;, score=0.881 total time=   0.3s
# [CV 8/10] END min_samples_leaf=10, n_estimators=70;, score=0.789 total time=   0.4s
# [CV 9/10] END min_samples_leaf=10, n_estimators=70;, score=0.729 total time=   0.4s
# [CV 10/10] END min_samples_leaf=10, n_estimators=70;, score=0.886 total time=   0.4s
# [CV 1/10] END min_samples_leaf=10, n_estimators=100;, score=0.823 total time=   0.5s
# [CV 2/10] END min_samples_leaf=10, n_estimators=100;, score=0.888 total time=   0.5s
# [CV 3/10] END min_samples_leaf=10, n_estimators=100;, score=0.816 total time=   0.5s
# [CV 4/10] END min_samples_leaf=10, n_estimators=100;, score=0.883 total time=   0.5s
# [CV 5/10] END min_samples_leaf=10, n_estimators=100;, score=0.861 total time=   0.5s
# [CV 6/10] END min_samples_leaf=10, n_estimators=100;, score=0.730 total time=   0.5s
# [CV 7/10] END min_samples_leaf=10, n_estimators=100;, score=0.881 total time=   0.5s
# [CV 8/10] END min_samples_leaf=10, n_estimators=100;, score=0.788 total time=   0.5s
# [CV 9/10] END min_samples_leaf=10, n_estimators=100;, score=0.730 total time=   0.5s
# [CV 10/10] END min_samples_leaf=10, n_estimators=100;, score=0.886 total time=   0.5s
# [CV 1/10] END min_samples_leaf=10, n_estimators=200;, score=0.822 total time=   1.0s
# [CV 2/10] END min_samples_leaf=10, n_estimators=200;, score=0.885 total time=   1.0s
# [CV 3/10] END min_samples_leaf=10, n_estimators=200;, score=0.812 total time=   1.0s
# [CV 4/10] END min_samples_leaf=10, n_estimators=200;, score=0.886 total time=   1.0s
# [CV 5/10] END min_samples_leaf=10, n_estimators=200;, score=0.861 total time=   1.0s
# [CV 6/10] END min_samples_leaf=10, n_estimators=200;, score=0.740 total time=   1.0s
# [CV 7/10] END min_samples_leaf=10, n_estimators=200;, score=0.881 total time=   1.0s
# [CV 8/10] END min_samples_leaf=10, n_estimators=200;, score=0.798 total time=   1.0s
# [CV 9/10] END min_samples_leaf=10, n_estimators=200;, score=0.731 total time=   1.0s
# [CV 10/10] END min_samples_leaf=10, n_estimators=200;, score=0.891 total time=   1.0s
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_leaf': [2, 5, 10],
#                          'n_estimators': [10, 30, 50, 70, 100, 200]},
#              verbose=3)

# %%
reg.best_estimator_
# Out:
# RandomForestRegressor(min_samples_leaf=2)

# %%
reg.best_score_
# Out:
# 0.8429373673324033

# %%
y_test = test['SalePrice']
X_test = test.drop(['SalePrice'], axis=1)

predictions = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test.values, predictions)
# Out:
# 0.893864606161802

# %%
mean_squared_error(y_test.values, predictions)
# Out:
# 636102588.8660995

# %%
for act, pred in zip(y_test.values[:5], predictions[:5]):
    print(f'y_ground_truth - {act}    y_prediction - {pred}')
# Out:
# y_ground_truth - 173900    y_prediction - 173295.4460952381
# y_ground_truth - 120000    y_prediction - 121887.19090476191
# y_ground_truth - 219210    y_prediction - 227557.45193650795
# y_ground_truth - 132500    y_prediction - 116961.18642857141
# y_ground_truth - 109500    y_prediction - 98171.10321428569

# %%
new_train = train[(np.abs(stats.zscore(train[final_numerical_cols])) < 5).all(axis=1)]

# %%
y = new_train['SalePrice']
X = new_train.drop(['SalePrice'], axis=1)
parameters = {'n_estimators' : [10,30, 50, 70, 100, 200], 'min_samples_leaf':[2,5,10]}
model = RandomForestRegressor()
reg = GridSearchCV(model, parameters, verbose=3,cv=10)
reg.fit(X, y)
# Out:
# Fitting 10 folds for each of 18 candidates, totalling 180 fits
# [CV 1/10] END min_samples_leaf=2, n_estimators=10;, score=0.833 total time=   0.1s
# [CV 2/10] END min_samples_leaf=2, n_estimators=10;, score=0.873 total time=   0.1s
# [CV 3/10] END min_samples_leaf=2, n_estimators=10;, score=0.856 total time=   0.1s
# [CV 4/10] END min_samples_leaf=2, n_estimators=10;, score=0.868 total time=   0.1s
# [CV 5/10] END min_samples_leaf=2, n_estimators=10;, score=0.891 total time=   0.1s
# [CV 6/10] END min_samples_leaf=2, n_estimators=10;, score=0.873 total time=   0.1s
# [CV 7/10] END min_samples_leaf=2, n_estimators=10;, score=0.863 total time=   0.1s
# [CV 8/10] END min_samples_leaf=2, n_estimators=10;, score=0.776 total time=   0.1s
# [CV 9/10] END min_samples_leaf=2, n_estimators=10;, score=0.857 total time=   0.1s
# [CV 10/10] END min_samples_leaf=2, n_estimators=10;, score=0.889 total time=   0.1s
# [CV 1/10] END min_samples_leaf=2, n_estimators=30;, score=0.849 total time=   0.2s
# [CV 2/10] END min_samples_leaf=2, n_estimators=30;, score=0.895 total time=   0.2s
# [CV 3/10] END min_samples_leaf=2, n_estimators=30;, score=0.874 total time=   0.2s
# [CV 4/10] END min_samples_leaf=2, n_estimators=30;, score=0.870 total time=   0.2s
# [CV 5/10] END min_samples_leaf=2, n_estimators=30;, score=0.891 total time=   0.2s
# [CV 6/10] END min_samples_leaf=2, n_estimators=30;, score=0.872 total time=   0.2s
# [CV 7/10] END min_samples_leaf=2, n_estimators=30;, score=0.868 total time=   0.2s
# [CV 8/10] END min_samples_leaf=2, n_estimators=30;, score=0.799 total time=   0.2s
# [CV 9/10] END min_samples_leaf=2, n_estimators=30;, score=0.878 total time=   0.2s
# [CV 10/10] END min_samples_leaf=2, n_estimators=30;, score=0.900 total time=   0.2s
# [CV 1/10] END min_samples_leaf=2, n_estimators=50;, score=0.849 total time=   0.4s
# [CV 2/10] END min_samples_leaf=2, n_estimators=50;, score=0.900 total time=   0.4s
# [CV 3/10] END min_samples_leaf=2, n_estimators=50;, score=0.874 total time=   0.3s
# [CV 4/10] END min_samples_leaf=2, n_estimators=50;, score=0.879 total time=   0.4s
# [CV 5/10] END min_samples_leaf=2, n_estimators=50;, score=0.901 total time=   0.4s
# [CV 6/10] END min_samples_leaf=2, n_estimators=50;, score=0.879 total time=   0.4s
# [CV 7/10] END min_samples_leaf=2, n_estimators=50;, score=0.864 total time=   0.4s
# [CV 8/10] END min_samples_leaf=2, n_estimators=50;, score=0.797 total time=   0.4s
# [CV 9/10] END min_samples_leaf=2, n_estimators=50;, score=0.888 total time=   0.4s
# [CV 10/10] END min_samples_leaf=2, n_estimators=50;, score=0.892 total time=   0.4s
# [CV 1/10] END min_samples_leaf=2, n_estimators=70;, score=0.855 total time=   0.5s
# [CV 2/10] END min_samples_leaf=2, n_estimators=70;, score=0.898 total time=   0.5s
# [CV 3/10] END min_samples_leaf=2, n_estimators=70;, score=0.874 total time=   0.5s
# [CV 4/10] END min_samples_leaf=2, n_estimators=70;, score=0.884 total time=   0.5s
# [CV 5/10] END min_samples_leaf=2, n_estimators=70;, score=0.893 total time=   0.5s
# [CV 6/10] END min_samples_leaf=2, n_estimators=70;, score=0.878 total time=   0.5s
# [CV 7/10] END min_samples_leaf=2, n_estimators=70;, score=0.872 total time=   0.5s
# [CV 8/10] END min_samples_leaf=2, n_estimators=70;, score=0.794 total time=   0.5s
# [CV 9/10] END min_samples_leaf=2, n_estimators=70;, score=0.883 total time=   0.5s
# [CV 10/10] END min_samples_leaf=2, n_estimators=70;, score=0.895 total time=   0.5s
# [CV 1/10] END min_samples_leaf=2, n_estimators=100;, score=0.846 total time=   0.7s
# [CV 2/10] END min_samples_leaf=2, n_estimators=100;, score=0.898 total time=   0.7s
# [CV 3/10] END min_samples_leaf=2, n_estimators=100;, score=0.873 total time=   0.7s
# [CV 4/10] END min_samples_leaf=2, n_estimators=100;, score=0.892 total time=   0.7s
# [CV 5/10] END min_samples_leaf=2, n_estimators=100;, score=0.901 total time=   0.7s
# [CV 6/10] END min_samples_leaf=2, n_estimators=100;, score=0.877 total time=   0.7s
# [CV 7/10] END min_samples_leaf=2, n_estimators=100;, score=0.878 total time=   0.7s
# [CV 8/10] END min_samples_leaf=2, n_estimators=100;, score=0.793 total time=   0.7s
# [CV 9/10] END min_samples_leaf=2, n_estimators=100;, score=0.884 total time=   0.7s
# [CV 10/10] END min_samples_leaf=2, n_estimators=100;, score=0.890 total time=   0.7s
# [CV 1/10] END min_samples_leaf=2, n_estimators=200;, score=0.851 total time=   1.4s
# [CV 2/10] END min_samples_leaf=2, n_estimators=200;, score=0.898 total time=   1.4s
# [CV 3/10] END min_samples_leaf=2, n_estimators=200;, score=0.878 total time=   1.5s
# [CV 4/10] END min_samples_leaf=2, n_estimators=200;, score=0.890 total time=   1.4s
# [CV 5/10] END min_samples_leaf=2, n_estimators=200;, score=0.897 total time=   1.4s
# [CV 6/10] END min_samples_leaf=2, n_estimators=200;, score=0.879 total time=   1.4s
# [CV 7/10] END min_samples_leaf=2, n_estimators=200;, score=0.878 total time=   1.4s
# [CV 8/10] END min_samples_leaf=2, n_estimators=200;, score=0.791 total time=   1.4s
# [CV 9/10] END min_samples_leaf=2, n_estimators=200;, score=0.893 total time=   1.4s
# [CV 10/10] END min_samples_leaf=2, n_estimators=200;, score=0.895 total time=   1.4s
# [CV 1/10] END min_samples_leaf=5, n_estimators=10;, score=0.782 total time=   0.1s
# [CV 2/10] END min_samples_leaf=5, n_estimators=10;, score=0.890 total time=   0.1s
# [CV 3/10] END min_samples_leaf=5, n_estimators=10;, score=0.850 total time=   0.1s
# [CV 4/10] END min_samples_leaf=5, n_estimators=10;, score=0.878 total time=   0.1s
# [CV 5/10] END min_samples_leaf=5, n_estimators=10;, score=0.884 total time=   0.1s
# [CV 6/10] END min_samples_leaf=5, n_estimators=10;, score=0.867 total time=   0.1s
# [CV 7/10] END min_samples_leaf=5, n_estimators=10;, score=0.864 total time=   0.1s
# [CV 8/10] END min_samples_leaf=5, n_estimators=10;, score=0.778 total time=   0.1s
# [CV 9/10] END min_samples_leaf=5, n_estimators=10;, score=0.859 total time=   0.1s
# [CV 10/10] END min_samples_leaf=5, n_estimators=10;, score=0.863 total time=   0.1s
# [CV 1/10] END min_samples_leaf=5, n_estimators=30;, score=0.836 total time=   0.2s
# [CV 2/10] END min_samples_leaf=5, n_estimators=30;, score=0.888 total time=   0.2s
# [CV 3/10] END min_samples_leaf=5, n_estimators=30;, score=0.857 total time=   0.2s
# [CV 4/10] END min_samples_leaf=5, n_estimators=30;, score=0.900 total time=   0.2s
# [CV 5/10] END min_samples_leaf=5, n_estimators=30;, score=0.896 total time=   0.2s
# [CV 6/10] END min_samples_leaf=5, n_estimators=30;, score=0.866 total time=   0.2s
# [CV 7/10] END min_samples_leaf=5, n_estimators=30;, score=0.870 total time=   0.2s
# [CV 8/10] END min_samples_leaf=5, n_estimators=30;, score=0.785 total time=   0.2s
# [CV 9/10] END min_samples_leaf=5, n_estimators=30;, score=0.879 total time=   0.2s
# [CV 10/10] END min_samples_leaf=5, n_estimators=30;, score=0.893 total time=   0.2s
# [CV 1/10] END min_samples_leaf=5, n_estimators=50;, score=0.844 total time=   0.3s
# [CV 2/10] END min_samples_leaf=5, n_estimators=50;, score=0.886 total time=   0.3s
# [CV 3/10] END min_samples_leaf=5, n_estimators=50;, score=0.861 total time=   0.3s
# [CV 4/10] END min_samples_leaf=5, n_estimators=50;, score=0.888 total time=   0.3s
# [CV 5/10] END min_samples_leaf=5, n_estimators=50;, score=0.897 total time=   0.3s
# [CV 6/10] END min_samples_leaf=5, n_estimators=50;, score=0.871 total time=   0.3s
# [CV 7/10] END min_samples_leaf=5, n_estimators=50;, score=0.874 total time=   0.3s
# [CV 8/10] END min_samples_leaf=5, n_estimators=50;, score=0.793 total time=   0.3s
# [CV 9/10] END min_samples_leaf=5, n_estimators=50;, score=0.886 total time=   0.3s
# [CV 10/10] END min_samples_leaf=5, n_estimators=50;, score=0.897 total time=   0.3s
# [CV 1/10] END min_samples_leaf=5, n_estimators=70;, score=0.841 total time=   0.4s
# [CV 2/10] END min_samples_leaf=5, n_estimators=70;, score=0.892 total time=   0.4s
# [CV 3/10] END min_samples_leaf=5, n_estimators=70;, score=0.855 total time=   0.4s
# [CV 4/10] END min_samples_leaf=5, n_estimators=70;, score=0.883 total time=   0.4s
# [CV 5/10] END min_samples_leaf=5, n_estimators=70;, score=0.900 total time=   0.4s
# [CV 6/10] END min_samples_leaf=5, n_estimators=70;, score=0.865 total time=   0.4s
# [CV 7/10] END min_samples_leaf=5, n_estimators=70;, score=0.875 total time=   0.4s
# [CV 8/10] END min_samples_leaf=5, n_estimators=70;, score=0.787 total time=   0.4s
# [CV 9/10] END min_samples_leaf=5, n_estimators=70;, score=0.885 total time=   0.4s
# [CV 10/10] END min_samples_leaf=5, n_estimators=70;, score=0.900 total time=   0.4s
# [CV 1/10] END min_samples_leaf=5, n_estimators=100;, score=0.844 total time=   0.6s
# [CV 2/10] END min_samples_leaf=5, n_estimators=100;, score=0.888 total time=   0.6s
# [CV 3/10] END min_samples_leaf=5, n_estimators=100;, score=0.862 total time=   0.6s
# [CV 4/10] END min_samples_leaf=5, n_estimators=100;, score=0.885 total time=   0.6s
# [CV 5/10] END min_samples_leaf=5, n_estimators=100;, score=0.894 total time=   0.6s
# [CV 6/10] END min_samples_leaf=5, n_estimators=100;, score=0.867 total time=   0.6s
# [CV 7/10] END min_samples_leaf=5, n_estimators=100;, score=0.871 total time=   0.6s
# [CV 8/10] END min_samples_leaf=5, n_estimators=100;, score=0.792 total time=   0.6s
# [CV 9/10] END min_samples_leaf=5, n_estimators=100;, score=0.892 total time=   0.6s
# [CV 10/10] END min_samples_leaf=5, n_estimators=100;, score=0.896 total time=   0.6s
# [CV 1/10] END min_samples_leaf=5, n_estimators=200;, score=0.840 total time=   1.1s
# [CV 2/10] END min_samples_leaf=5, n_estimators=200;, score=0.891 total time=   1.1s
# [CV 3/10] END min_samples_leaf=5, n_estimators=200;, score=0.864 total time=   1.1s
# [CV 4/10] END min_samples_leaf=5, n_estimators=200;, score=0.885 total time=   1.1s
# [CV 5/10] END min_samples_leaf=5, n_estimators=200;, score=0.898 total time=   1.1s
# [CV 6/10] END min_samples_leaf=5, n_estimators=200;, score=0.874 total time=   1.2s
# [CV 7/10] END min_samples_leaf=5, n_estimators=200;, score=0.872 total time=   1.1s
# [CV 8/10] END min_samples_leaf=5, n_estimators=200;, score=0.789 total time=   1.1s
# [CV 9/10] END min_samples_leaf=5, n_estimators=200;, score=0.888 total time=   1.1s
# [CV 10/10] END min_samples_leaf=5, n_estimators=200;, score=0.896 total time=   1.1s
# [CV 1/10] END min_samples_leaf=10, n_estimators=10;, score=0.816 total time=   0.1s
# [CV 2/10] END min_samples_leaf=10, n_estimators=10;, score=0.882 total time=   0.1s
# [CV 3/10] END min_samples_leaf=10, n_estimators=10;, score=0.837 total time=   0.0s
# [CV 4/10] END min_samples_leaf=10, n_estimators=10;, score=0.883 total time=   0.1s
# [CV 5/10] END min_samples_leaf=10, n_estimators=10;, score=0.889 total time=   0.1s
# [CV 6/10] END min_samples_leaf=10, n_estimators=10;, score=0.876 total time=   0.1s
# [CV 7/10] END min_samples_leaf=10, n_estimators=10;, score=0.852 total time=   0.1s
# [CV 8/10] END min_samples_leaf=10, n_estimators=10;, score=0.741 total time=   0.1s
# [CV 9/10] END min_samples_leaf=10, n_estimators=10;, score=0.871 total time=   0.1s
# [CV 10/10] END min_samples_leaf=10, n_estimators=10;, score=0.889 total time=   0.1s
# [CV 1/10] END min_samples_leaf=10, n_estimators=30;, score=0.823 total time=   0.1s
# [CV 2/10] END min_samples_leaf=10, n_estimators=30;, score=0.873 total time=   0.1s
# [CV 3/10] END min_samples_leaf=10, n_estimators=30;, score=0.852 total time=   0.1s
# [CV 4/10] END min_samples_leaf=10, n_estimators=30;, score=0.886 total time=   0.1s
# [CV 5/10] END min_samples_leaf=10, n_estimators=30;, score=0.887 total time=   0.1s
# [CV 6/10] END min_samples_leaf=10, n_estimators=30;, score=0.859 total time=   0.1s
# [CV 7/10] END min_samples_leaf=10, n_estimators=30;, score=0.862 total time=   0.1s
# [CV 8/10] END min_samples_leaf=10, n_estimators=30;, score=0.770 total time=   0.1s
# [CV 9/10] END min_samples_leaf=10, n_estimators=30;, score=0.892 total time=   0.1s
# [CV 10/10] END min_samples_leaf=10, n_estimators=30;, score=0.886 total time=   0.1s
# [CV 1/10] END min_samples_leaf=10, n_estimators=50;, score=0.831 total time=   0.2s
# [CV 2/10] END min_samples_leaf=10, n_estimators=50;, score=0.876 total time=   0.2s
# [CV 3/10] END min_samples_leaf=10, n_estimators=50;, score=0.855 total time=   0.2s
# [CV 4/10] END min_samples_leaf=10, n_estimators=50;, score=0.870 total time=   0.2s
# [CV 5/10] END min_samples_leaf=10, n_estimators=50;, score=0.887 total time=   0.2s
# [CV 6/10] END min_samples_leaf=10, n_estimators=50;, score=0.864 total time=   0.2s
# [CV 7/10] END min_samples_leaf=10, n_estimators=50;, score=0.862 total time=   0.2s
# [CV 8/10] END min_samples_leaf=10, n_estimators=50;, score=0.775 total time=   0.2s
# [CV 9/10] END min_samples_leaf=10, n_estimators=50;, score=0.883 total time=   0.2s
# [CV 10/10] END min_samples_leaf=10, n_estimators=50;, score=0.883 total time=   0.2s
# [CV 1/10] END min_samples_leaf=10, n_estimators=70;, score=0.839 total time=   0.3s
# [CV 2/10] END min_samples_leaf=10, n_estimators=70;, score=0.873 total time=   0.3s
# [CV 3/10] END min_samples_leaf=10, n_estimators=70;, score=0.839 total time=   0.3s
# [CV 4/10] END min_samples_leaf=10, n_estimators=70;, score=0.878 total time=   0.4s
# [CV 5/10] END min_samples_leaf=10, n_estimators=70;, score=0.889 total time=   0.3s
# [CV 6/10] END min_samples_leaf=10, n_estimators=70;, score=0.856 total time=   0.4s
# [CV 7/10] END min_samples_leaf=10, n_estimators=70;, score=0.866 total time=   0.3s
# [CV 8/10] END min_samples_leaf=10, n_estimators=70;, score=0.776 total time=   0.3s
# [CV 9/10] END min_samples_leaf=10, n_estimators=70;, score=0.882 total time=   0.3s
# [CV 10/10] END min_samples_leaf=10, n_estimators=70;, score=0.884 total time=   0.3s
# [CV 1/10] END min_samples_leaf=10, n_estimators=100;, score=0.831 total time=   0.5s
# [CV 2/10] END min_samples_leaf=10, n_estimators=100;, score=0.874 total time=   0.5s
# [CV 3/10] END min_samples_leaf=10, n_estimators=100;, score=0.843 total time=   0.5s
# [CV 4/10] END min_samples_leaf=10, n_estimators=100;, score=0.885 total time=   0.5s
# [CV 5/10] END min_samples_leaf=10, n_estimators=100;, score=0.889 total time=   0.5s
# [CV 6/10] END min_samples_leaf=10, n_estimators=100;, score=0.860 total time=   0.5s
# [CV 7/10] END min_samples_leaf=10, n_estimators=100;, score=0.862 total time=   0.6s
# [CV 8/10] END min_samples_leaf=10, n_estimators=100;, score=0.775 total time=   0.6s
# [CV 9/10] END min_samples_leaf=10, n_estimators=100;, score=0.886 total time=   0.5s
# [CV 10/10] END min_samples_leaf=10, n_estimators=100;, score=0.885 total time=   0.5s
# [CV 1/10] END min_samples_leaf=10, n_estimators=200;, score=0.831 total time=   1.0s
# [CV 2/10] END min_samples_leaf=10, n_estimators=200;, score=0.878 total time=   0.9s
# [CV 3/10] END min_samples_leaf=10, n_estimators=200;, score=0.846 total time=   0.9s
# [CV 4/10] END min_samples_leaf=10, n_estimators=200;, score=0.878 total time=   1.0s
# [CV 5/10] END min_samples_leaf=10, n_estimators=200;, score=0.890 total time=   1.0s
# [CV 6/10] END min_samples_leaf=10, n_estimators=200;, score=0.863 total time=   1.0s
# [CV 7/10] END min_samples_leaf=10, n_estimators=200;, score=0.862 total time=   1.0s
# [CV 8/10] END min_samples_leaf=10, n_estimators=200;, score=0.776 total time=   1.0s
# [CV 9/10] END min_samples_leaf=10, n_estimators=200;, score=0.882 total time=   1.0s
# [CV 10/10] END min_samples_leaf=10, n_estimators=200;, score=0.884 total time=   1.0s
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'min_samples_leaf': [2, 5, 10],
#                          'n_estimators': [10, 30, 50, 70, 100, 200]},
#              verbose=3)

# %%
y_test = test['SalePrice']
X_test = test.drop(['SalePrice'], axis=1)

predictions = reg.predict(X_test)
r2_score(y_test.values, predictions)
# Out:
# 0.8662816782049596
